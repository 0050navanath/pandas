# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the dataset and display first 10 rows

# %%
df=pd.read_csv('C:\\Users\\YASH\\Documents\\bmw_car_data.csv')
df.head(10)
# Out:
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019  Electric          Manual       1496
# 1   2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2   3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010  Electric          Manual       2993
# 5   6         X1      M Sport  2012    Petrol          Manual       2993
# 6   7         M3     Standard  2014    Hybrid  Semi-Automatic       4395
# 7   8       320d   Sport Line  2015  Electric  Semi-Automatic       1496
# 8   9         X3   Sport Line  2019  Electric          Manual       1998
# 9  10         i8  Luxury Line  2015    Petrol          Manual       1998
#
#    Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 0     395.18     492.04         20.48              68.33          Second
# ...

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Display shape

# %%
df.shape
# Out:
# (100000, 15)

# %% [markdown]
# # display columns

# %%
df.columns
# Out:
# Index(['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission',
#        'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl',
#        'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location',
#        'Registration_State'],
#       dtype='object')

# %% [markdown]
# # Display data type

# %%
df.dtypes
# Out:
# ID                        int64
# Model_Name               object
# Variant                  object
# Year                      int64
# Fuel_Type                object
# Transmission             object
# Engine_CC                 int64
# Power_BHP               float64
# Torque_Nm               float64
# Mileage_kmpl            float64
# Price_Ex_Showroom       float64
# Owner_Type               object
# Insurance_Valid_Till      int64
# Location                 object
# Registration_State       object
# dtype: object

# %%
df=pd.read_csv('C:\\Users\\YASH\\Documents\\bmw_car_data.csv')
df.head(10)
# Out:
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019  Electric          Manual       1496
# 1   2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2   3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010  Electric          Manual       2993
# 5   6         X1      M Sport  2012    Petrol          Manual       2993
# 6   7         M3     Standard  2014    Hybrid  Semi-Automatic       4395
# 7   8       320d   Sport Line  2015  Electric  Semi-Automatic       1496
# 8   9         X3   Sport Line  2019  Electric          Manual       1998
# 9  10         i8  Luxury Line  2015    Petrol          Manual       1998
#
#    Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 0     395.18     492.04         20.48              68.33          Second
# ...

# %% [markdown]
# # for display missing values and count per columns

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# ID                      0
# Model_Name              0
# Variant                 0
# Year                    0
# Fuel_Type               0
# Transmission            0
# Engine_CC               0
# Power_BHP               0
# Torque_Nm               0
# Mileage_kmpl            0
# Price_Ex_Showroom       0
# Owner_Type              0
# Insurance_Valid_Till    0
# Location                0
# Registration_State      0
# dtype: int64

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # filter cars manufactured after 2020

# %%
df[df['Year']>2020]
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 10        11         i8   Sport Line  2024    Diesel       Manual       4395
# 16        17         M4     Standard  2022    Hybrid    Automatic       4395
# 22        23         M4     Standard  2023    Hybrid       Manual       4395
# 24        25         X3   Sport Line  2022    Hybrid    Automatic       1998
# 27        28         X7     Standard  2022    Diesel    Automatic       2993
# ...      ...        ...          ...   ...       ...          ...        ...
# 99986  99987         Z4     Standard  2021    Diesel       Manual       4395
# 99987  99988         X1     Standard  2023    Hybrid       Manual       2993
# 99991  99992         X1  Luxury Line  2023    Hybrid    Automatic       1496
# 99992  99993         Z4      M Sport  2021    Hybrid       Manual       1496
# 99996  99997         Z4   Sport Line  2021  Electric    Automatic       1496
#
# ...

# %% [markdown]
# # list unique car models

# %%
df['Model_Name'].nunique()
# Out:
# 10

# %% [markdown]
# # list unique values of fuel type

# %%
df['Fuel_Type'].nunique()
# Out:
# 4

# %% [markdown]
# # 6.Count how many cars per fuel type.

# %%
df['Fuel_Type'].value_counts().T
# Out:
# Fuel_Type
# Petrol      25125
# Diesel      25089
# Hybrid      24934
# Electric    24852
# Name: count, dtype: int64

# %% [markdown]
# # 7.Sort dataset by Price_Ex_Showroom descending.

# %%
df.sort_values(by=['Price_Ex_Showroom'],ascending=False).head(5)
# Out:
#           ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 71910  71911         X1  Luxury Line  2016    Diesel  Semi-Automatic
# 62468  62469       520d      M Sport  2016    Hybrid  Semi-Automatic
# 86274  86275         X7      M Sport  2024    Petrol          Manual
# 97582  97583         X7      M Sport  2012    Petrol          Manual
# 57442  57443         M3     Standard  2013    Hybrid  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# 71910       1998     370.37     693.15          9.58              135.0
# 62468       1496     499.83     719.86         24.54              135.0
# 86274       4395     374.25     350.79         19.55              135.0
# 97582       1496     589.90     538.34         22.72              135.0
# 57442       1496     583.38     651.80         13.82              135.0
#
#            Owner_Type  Insurance_Valid_Till   Location Registration_State
# ...

# %% [markdown]
# # 8.Filter only Automatic transmission BMWs.

# %%
condition2 =df['Transmission'] == 'Automatic'
df[condition2].head(10)
# Out:
#     ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 1    2         X5  Luxury Line  2016  Electric    Automatic       1496
# 11  12         X7      M Sport  2019    Hybrid    Automatic       1998
# 14  15         M3     Standard  2017    Hybrid    Automatic       4395
# 16  17         M4     Standard  2022    Hybrid    Automatic       4395
# 20  21         X5   Sport Line  2010    Hybrid    Automatic       1496
# 23  24         X1     Standard  2011  Electric    Automatic       1998
# 24  25         X3   Sport Line  2022    Hybrid    Automatic       1998
# 27  28         X7     Standard  2022    Diesel    Automatic       2993
# 28  29         X3     Standard  2012    Hybrid    Automatic       1496
# 29  30         i8       xDrive  2023    Petrol    Automatic       1998
#
#     Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 1      312.78     708.05          8.12             118.58          Second
# ...

# %% [markdown]
# # 9.Replace missing mileage values with mean.

# %%
mean_Mileage_kmpl = df['Mileage_kmpl'].mean()
df['Mileage_kmpl'].fillna(mean_Mileage_kmpl,inplace= True)
df
mean_Mileage_kmpl
# Out:
# C:\Users\YASH\AppData\Local\Temp\ipykernel_7572\1770408799.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage_kmpl'].fillna(mean_Mileage_kmpl,inplace= True)
# np.float64(16.490543700000003)

# %% [markdown]
# # 10.Drop rows where Engine_CC is null.

# %%
df =df.copy()

# %%
df.dropna(subset =['Engine_CC'], inplace=True)
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# ### 11.Group cars by Model_Name and calculate average price.

# %%
df[['Price_Ex_Showroom']].groupby (df['Model_Name']).mean()
# Out:
#             Price_Ex_Showroom
# Model_Name
# 320d                85.361262
# 520d                85.270653
# M3                  85.090345
# M4                  85.223891
# X1                  84.612881
# X3                  85.528270
# X5                  85.401622
# X7                  84.835493
# Z4                  85.307179
# i8                  85.086266

# %% [markdown]
# # 12.Create a new column Car_Age = 2025 - Year.

# %%
df['Car_Age'] = 2025- df['Year']

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# ## 13.Filter cars priced above ₹60 lakh

# %%
condition3 = df['Price_Ex_Showroom'] >= 60

# %%
df[condition3].head(70)
# Out:
#     ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0    1         X5       xDrive  2019  Electric          Manual       1496
# 1    2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2    3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 4    5         X7       xDrive  2010  Electric          Manual       2993
# 5    6         X1      M Sport  2012    Petrol          Manual       2993
# ..  ..        ...          ...   ...       ...             ...        ...
# 85  86         i8   Sport Line  2019  Electric  Semi-Automatic       4395
# 87  88         X5  Luxury Line  2022    Hybrid          Manual       1998
# 88  89       320d  Luxury Line  2024    Petrol          Manual       4395
# 89  90         M4      M Sport  2023    Petrol  Semi-Automatic       1998
# 90  91         X3  Luxury Line  2011    Diesel          Manual       4395
#
#     Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# ...

# %% [markdown]
# ### 14.Find top 5 most common cities in the dataset.

# %%
df['Location'].value_counts().sort_values(ascending = False).head(5)
# Out:
# Location
# Ahmedabad    12668
# Chennai      12549
# Mumbai       12495
# Bangalore    12492
# Delhi        12478
# Name: count, dtype: int64

# %% [markdown]
# # 15.Plot histogram for mileage.¶

# %% [markdown]
# # 16.Create a bar chart of fuel type vs average power.

# %% [markdown]
# # 17.Apply .loc[] to update fuel type of electric variants.

# %%
df.loc[df.Fuel_Type =="Electric",'Fuel_Type'] ='Battary'

# %%
df.head()
# Out:
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019   Battary          Manual       1496
# 1   2         X5  Luxury Line  2016   Battary       Automatic       1496
# 2   3         Z4      M Sport  2012   Battary  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010   Battary          Manual       2993
#
#    Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 0     395.18     492.04         20.48              68.33          Second
# 1     312.78     708.05          8.12             118.58          Second
# 2     604.45     550.74         16.24             109.90          Second
# 3     383.04     413.78          9.80              41.05  Fourth & Above
# 4     315.78     632.13         23.47             111.08           First
#
#    Insurance_Valid_Till   Location Registration_State  Car_Age
# ...

# %% [markdown]
# # 18.Convert Price_Ex_Showroom from lakh to ₹ value.

# %%
df['Price_Ex_Showroom'] *100000
# Out:
# 0         6833000.0
# 1        11858000.0
# 2        10990000.0
# 3         4105000.0
# 4        11108000.0
#             ...
# 99995     9915000.0
# 99996     7056000.0
# 99997     4446000.0
# 99998     8482000.0
# 99999     7714000.0
# Name: Price_Ex_Showroom, Length: 100000, dtype: float64

# %% [markdown]
# # 19.Find how many cars are older than 10 years.

# %%
condition4 = df['Car_Age'] >10

# %%
 df[condition4]
# Out:
#           ID Model_Name     Variant  Year Fuel_Type    Transmission  \
# 2          3         Z4     M Sport  2012   Battary  Semi-Automatic
# 3          4         X7     M Sport  2013    Hybrid  Semi-Automatic
# 4          5         X7      xDrive  2010   Battary          Manual
# 5          6         X1     M Sport  2012    Petrol          Manual
# 6          7         M3    Standard  2014    Hybrid  Semi-Automatic
# ...      ...        ...         ...   ...       ...             ...
# 99984  99985         X1    Standard  2011    Diesel          Manual
# 99990  99991         X5      xDrive  2013    Petrol       Automatic
# 99993  99994         X3     M Sport  2011    Hybrid          Manual
# 99995  99996         Z4  Sport Line  2014    Hybrid  Semi-Automatic
# 99997  99998         M4    Standard  2012    Hybrid       Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# 2           4395     604.45     550.74         16.24             109.90
# ...

# %% [markdown]
# # 20.Count of cars by Owner_Type and Transmission.

# %%
df[['Owner_Type','Transmission']].groupby (df['Owner_Type']).count()
# Out:
#                 Owner_Type  Transmission
# Owner_Type
# First                25042         25042
# Fourth & Above       24991         24991
# Second               24964         24964
# Third                25003         25003

# %% [markdown]
# # 21.Find maximum BHP in diesel cars.

# %%
condition4 = df['Fuel_Type'] == 'Diesel'

# %%
df[['Fuel_Type','Power_BHP']].groupby (df['Fuel_Type']=='Diesel').max()
# Out:
#           Fuel_Type  Power_BHP
# Fuel_Type
# False        Petrol     624.99
# True         Diesel     624.98

# %% [markdown]
# # 22.Plot scatter plot of Engine_CC vs Price.

# %% [markdown]
# # 23.Count number of variants per model.

# %%
df[['Variant']].groupby (df['Model_Name']).count()
# Out:
#             Variant
# Model_Name
# 320d           9888
# 520d           9985
# M3             9947
# M4            10020
# X1            10093
# X3            10141
# X5             9903
# X7            10132
# Z4            10026
# i8             9865

# %% [markdown]
# # 24.Find car with max and min mileage.

# %%
Mileage_kmpl_minMax =df[['Model_Name','Mileage_kmpl']].groupby(['Model_Name']).agg(['min','max'])

# %%
Mileage_kmpl_minMax
# Out:
#            Mileage_kmpl
#                     min   max
# Model_Name
# 320d               8.00  25.0
# 520d               8.00  25.0
# M3                 8.00  25.0
# M4                 8.00  25.0
# X1                 8.00  25.0
# X3                 8.00  25.0
# X5                 8.00  25.0
# X7                 8.00  25.0
# Z4                 8.00  25.0
# i8                 8.01  25.0

# %% [markdown]
# # 25.Calculate median price per year.

# %%
df[['Price_Ex_Showroom']].groupby (df['Year']).median()
# Out:
#       Price_Ex_Showroom
# Year
# 2010             85.990
# 2011             85.585
# 2012             84.855
# 2013             84.930
# 2014             84.840
# 2015             85.570
# 2016             85.460
# 2017             85.020
# 2018             85.090
# 2019             84.850
# 2020             85.150
# 2021             85.890
# 2022             85.265
# 2023             84.850
# 2024             85.240

# %% [markdown]
# # 26.Pivot table with Location vs Fuel_Type.

# %% [markdown]
# # 27.Create a column Is_Luxury (if Price > ₹70L = Yes).

# %%
df['Is_Luxury'] = df['Price_Ex_Showroom']>70

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019   Battary          Manual
# 1           2         X5  Luxury Line  2016   Battary       Automatic
# 2           3         Z4      M Sport  2012   Battary  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010   Battary          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021   Battary       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015   Battary          Manual
# 99999  100000       520d  Luxury Line  2020   Battary  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # 28.Remove duplicate rows if any.

# %%
df =df.copy()

# %%
df.drop_duplicates (keep = 'first', inplace = True)
df.drop_duplicates()
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019   Battary          Manual
# 1           2         X5  Luxury Line  2016   Battary       Automatic
# 2           3         Z4      M Sport  2012   Battary  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010   Battary          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021   Battary       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015   Battary          Manual
# 99999  100000       520d  Luxury Line  2020   Battary  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # 29.Apply filter: Diesel + Automatic + Above 200 BHP.

# %%
filtered_df = df[
    (df['Fuel_Type'].str.lower() == 'diesel') &  
    (df['Transmission'].str.lower() == 'automatic') &
    (df['Power_BHP'] > 200)
]
print(filtered_df)
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 45        46         X3       xDrive  2016    Diesel    Automatic       1998
# 77        78         Z4  Luxury Line  2019    Diesel    Automatic       1998
# 118      119       520d      M Sport  2011    Diesel    Automatic       1998
# 127      128       520d      M Sport  2016    Diesel    Automatic       1496
# 138      139         Z4  Luxury Line  2024    Diesel    Automatic       4395
# ...      ...        ...          ...   ...       ...          ...        ...
# 99903  99904         Z4       xDrive  2012    Diesel    Automatic       4395
# 99919  99920       320d   Sport Line  2021    Diesel    Automatic       4395
# 99926  99927       520d     Standard  2021    Diesel    Automatic       1998
# 99934  99935         M3  Luxury Line  2018    Diesel    Automatic       4395
# 99947  99948         X7   Sport Line  2012    Diesel    Automatic       1998
#
# ...

# %% [markdown]
# # 30.Export filtered data to new CSV.
